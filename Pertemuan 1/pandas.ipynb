# %% [markdown]
# # Eksplorasi Dataframe Dengan Pandas
# - Nama : Haikal Raditya Fadhilah
# - NIM : 21.11.3910
# - Kelas : Informatika 02

# %%
# Library Python
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Membaca Data Csv
df = pd.read_csv('./diabetes.csv')
# Memampilkan Data 5 Teratas
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Menampilkan Data 5 Terbawah
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# Menampikan Jumlah Kolom Dan Baris
df.shape
# Out:
# (768, 9)

# %%
# Menampilkan Nama Coloumn Dari DataFrame
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Menampilkan Tipe Data Setiap Coloum
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Jumlah Data Outcome Data 1 Dan 0
df[['Outcome']].groupby('Outcome').size().to_frame('Jumlah')
# Out:
#          Jumlah
# Outcome
# 0           500
# 1           268

# %%
# Rata-Rata Colom Age
df['Age'].mean()
# Out:
# 33.240885416666664

# %%
# Nilai Min Dari Column Glucose
df['Glucose'].min()
# Out:
# 0

# %%
# Nilai Maksimal Dari Column Glucose
df['Glucose'].max()
# Out:
# 199

# %%
# Nomer 1
df[df['Outcome'] == 1].head(10)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 2             8      183             64              0        0  23.3
# 4             0      137             40             35      168  43.1
# 6             3       78             50             32       88  31.0
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 11           10      168             74              0        0  38.0
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
# 15            7      100              0              0        0  30.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# 2                      0.672   32        1
# 4                      2.288   33        1
# ...

# %%
# Nomer 2
df_1_bp_50 = df[df['Outcome'] == 1]
df_1_bp_50 = df_1_bp_50[df_1_bp_50['BloodPressure'] > 50]
df_1_bp_50.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 748                     0.408   36        1
# 749                     0.178   50        1
# 750                     1.182   22        1
# ...

# %%
df_1_bp_50.shape
# Out:
# (244, 9)
